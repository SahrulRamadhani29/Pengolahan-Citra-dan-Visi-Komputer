# %% [markdown]
# # D2 - Pengenalan Python untuk Membaca dan Menampilkan Image
# Kode panduan di bawah ditulis mengikuti Modul 1 Praktikum PCVK.

# %% [markdown]
# ## Langkah (Step) 1 - Import Library

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ## Langkah (Step) 2 - Baca Image dari URL

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                         #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))       #concatenate image
  cv2_imshow(final_frame)                          #show image
  print('\n')

# %% [markdown]
# ## Langkah (Step) 3 - Melihat Ukuran File Image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)

# %% [markdown]
# ## Langkah (Step) 4 - Mengakses Pixel

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
    image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# %% [markdown]
# # Pertanyaan Praktikum D2
#
# ## 1. Mengapa eksekusi Python menggunakan Google Colab?
# Google Colab dapat digunakan melalui browser tanpa instalasi lokal, sudah menyediakan banyak library, terintegrasi dengan Google Drive dan GitHub, serta memudahkan notebook untuk dijalankan dan dibagikan.
#
# ## 2. Kegunaan library
# - NumPy: manipulasi array numerik dan piksel.
# - Pandas: pengolahan data tabular.
# - OpenCV/cv2: membaca dan mengolah citra.
# - cv2_imshow: menampilkan citra OpenCV di Colab.
# - skimage.io: membaca citra, termasuk dari URL.
# - skimage.transform: transformasi citra.
# - PIL: membaca dan memanipulasi image.
# - Matplotlib: menampilkan citra dalam plot.
# Tidak semua library harus dipakai pada setiap langkah; penggunaannya menyesuaikan operasi yang dilakukan.
#
# ## 3. Kegunaan resize
# `cv.resize(image, (0,0), fx=0.5, fy=0.5)` mengubah tinggi dan lebar citra menjadi setengah ukuran semula. Jika tidak dilakukan, citra tetap berukuran asli dan membutuhkan ruang tampilan serta pemrosesan lebih besar.
#
# ## 4. Kegunaan `[255,255,255]`
# Nilai tersebut memberikan intensitas maksimum pada tiga channel warna sehingga piksel menjadi putih.
#
# ## 5. Keterkaitan pixel dan resolusi
# Resolusi menyatakan jumlah piksel dalam dimensi tinggi dan lebar. Semakin banyak piksel, semakin tinggi resolusi dan umumnya semakin banyak detail yang dapat disimpan.

# %% [markdown]
# # Tugas Praktikum D2
# Kode berikut adalah pengerjaan tugas, terpisah dari kode panduan PDF.

# %% [markdown]
# ## Tugas 2 - Garis Vertikal dan Garis Menyilang Diagonal

# %%
image_tugas2 = image_2.copy()
tinggi, lebar = image_tugas2.shape[:2]

for y in range(tinggi):
    image_tugas2[y, int(lebar/2)] = [255,255,255]

for i in range(min(tinggi, lebar)):
    image_tugas2[i, i] = [255,255,255]
    image_tugas2[i, lebar-i-1] = [255,255,255]

final_frame = cv.hconcat((image_2, image_tugas2))
cv2_imshow(final_frame)

# %% [markdown]
# ## Tugas 3 - Garis Horizontal Putih dengan Panjang Tertentu

# %%
image_tugas3 = image_2.copy()
tinggi, lebar = image_tugas3.shape[:2]

for y in range(int(lebar/4), int(3*lebar/4)):
    image_tugas3[int(tinggi/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_tugas3))
cv2_imshow(final_frame)

# %% [markdown]
# ## Tugas 4 - Kotak Putih Menggunakan Kumpulan Pixel

# %%
image_tugas4 = image_2.copy()
tinggi, lebar = image_tugas4.shape[:2]

for x in range(int(tinggi/3), int(2*tinggi/3)):
    for y in range(int(lebar/3), int(2*lebar/3)):
        image_tugas4[x, y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_tugas4))
cv2_imshow(final_frame)
